# %% [markdown]
# ## One-dimensional 1PL-IRT (Rasch) simulation

# %%
import os
os.chdir("../..")
import numpy as np
import pandas as pd
import scipy.stats as stats
from config.constants import SEEDS, DATA_PATH
from src.utils.sim import save_resp_matrix
from src.utils.misc import set_random_seeds, sigmoid

# %%
# hyperparameters
NUM_STUDENTS = [25, 50, 75, 100, 150, 200, 250, 300, 350, 400, 450, 500]
NUM_COURSES = 19
COURSE_PROP = 0.71  # proportion of courses average student took

# controls IRT parameters
ABILITY_VAR = 1
DIFF_VAR = 1

# %%
def generate_1pl_parameters(num_stud):
    thetas = stats.norm.rvs(loc=0.0, scale=ABILITY_VAR, size=num_stud)
    diffs = stats.norm.rvs(loc=0.0, scale=DIFF_VAR, size=NUM_COURSES)
    return thetas, diffs

def prob_1pl_correct(theta, diff):
    return sigmoid(theta - diff)

def create_resp_matrix(thetas, diffs, prop=COURSE_PROP):
    resp_matrix = []
    for t in thetas:
        cor_prob = prob_1pl_correct(t, diffs)
        resp_vec = (np.random.random(diffs.shape[0]) <= cor_prob).astype(int)
        mask = stats.bernoulli.rvs(1 - prop, size=diffs.shape[0])
        resp_vec[mask.astype(bool)] = -1  # indicate missing responses
        resp_matrix.append(resp_vec)
    return np.vstack(resp_matrix)

# %%
# generate simulation data
for num_stud in NUM_STUDENTS:
    for seed in SEEDS:
        set_random_seeds(seed)
        thetas, diffs = generate_1pl_parameters(num_stud)
        mat = create_resp_matrix(thetas, diffs, prop=COURSE_PROP)
        print(seed, "- empirical density:", np.mean(mat != -1))

        suffix = "_n=" + str(num_stud) + "_s=" + str(seed) + ".csv"
        # save response matrix
        resp_path = DATA_PATH["sim"] + "1d_1pl/data" + suffix 
        save_resp_matrix(mat, resp_path)

        # save model parameters
        theta_path = DATA_PATH["sim"] + "1d_1pl/theta" + suffix
        df = pd.DataFrame(thetas, columns=["theta"])
        df.to_csv(theta_path, index=False)

        course_path = DATA_PATH["sim"] + "1d_1pl/difficulty" + suffix
        df = pd.DataFrame(np.vstack([diffs]).T, columns=["difficulty"])
        df.to_csv(course_path, index=False)
# Out:
# 0 - empirical density: 0.7031578947368421
# 1 - empirical density: 0.7136842105263158
# 2 - empirical density: 0.7452631578947368
# 3 - empirical density: 0.6968421052631579
# 4 - empirical density: 0.7073684210526315
# 5 - empirical density: 0.7094736842105264
# 6 - empirical density: 0.7178947368421053
# 7 - empirical density: 0.6968421052631579
# 8 - empirical density: 0.7178947368421053
# 9 - empirical density: 0.7073684210526315
# 10 - empirical density: 0.728421052631579
# 11 - empirical density: 0.6989473684210527
# 12 - empirical density: 0.6842105263157895
# 13 - empirical density: 0.7052631578947368
# 14 - empirical density: 0.7178947368421053
# 15 - empirical density: 0.7052631578947368
# 16 - empirical density: 0.7115789473684211
# 17 - empirical density: 0.7178947368421053
# 18 - empirical density: 0.7263157894736842
# 19 - empirical density: 0.728421052631579
# 0 - empirical density: 0.6747368421052632
# 1 - empirical density: 0.7021052631578948
# 2 - empirical density: 0.7357894736842105
# 3 - empirical density: 0.7126315789473684
# 4 - empirical density: 0.7147368421052631
# 5 - empirical density: 0.6873684210526316
# 6 - empirical density: 0.7031578947368421
# 7 - empirical density: 0.74
# 8 - empirical density: 0.7315789473684211
# 9 - empirical density: 0.7252631578947368
# 10 - empirical density: 0.6978947368421052
# 11 - empirical density: 0.7147368421052631
# 12 - empirical density: 0.7063157894736842
# 13 - empirical density: 0.6968421052631579
# 14 - empirical density: 0.6968421052631579
# 15 - empirical density: 0.6736842105263158
# 16 - empirical density: 0.7273684210526316
# 17 - empirical density: 0.7042105263157895
# 18 - empirical density: 0.7336842105263158
# 19 - empirical density: 0.716842105263158
# 0 - empirical density: 0.6828070175438596
# 1 - empirical density: 0.7066666666666667
# 2 - empirical density: 0.7312280701754386
# 3 - empirical density: 0.7221052631578947
# 4 - empirical density: 0.7087719298245614
# 5 - empirical density: 0.7080701754385965
# 6 - empirical density: 0.6926315789473684
# 7 - empirical density: 0.728421052631579
# 8 - empirical density: 0.7263157894736842
# 9 - empirical density: 0.7143859649122807
# 10 - empirical density: 0.6940350877192982
# 11 - empirical density: 0.7101754385964912
# 12 - empirical density: 0.7291228070175438
# 13 - empirical density: 0.7150877192982457
# 14 - empirical density: 0.703859649122807
# 15 - empirical density: 0.6933333333333334
# 16 - empirical density: 0.7129824561403508
# 17 - empirical density: 0.7059649122807018
# 18 - empirical density: 0.7452631578947368
# 19 - empirical density: 0.727719298245614
# 0 - empirical density: 0.7078947368421052
# 1 - empirical density: 0.7073684210526315
# 2 - empirical density: 0.7189473684210527
# 3 - empirical density: 0.716842105263158
# 4 - empirical density: 0.7105263157894737
# 5 - empirical density: 0.7142105263157895
# 6 - empirical density: 0.6842105263157895
# 7 - empirical density: 0.7252631578947368
# 8 - empirical density: 0.72
# 9 - empirical density: 0.7163157894736842
# 10 - empirical density: 0.7173684210526315
# 11 - empirical density: 0.7078947368421052
# 12 - empirical density: 0.7231578947368421
# 13 - empirical density: 0.7178947368421053
# 14 - empirical density: 0.7147368421052631
# 15 - empirical density: 0.7052631578947368
# 16 - empirical density: 0.7152631578947368
# 17 - empirical density: 0.7110526315789474
# 18 - empirical density: 0.7505263157894737
# 19 - empirical density: 0.7194736842105263
# 0 - empirical density: 0.7214035087719298
# 1 - empirical density: 0.6971929824561404
# 2 - empirical density: 0.7133333333333334
# 3 - empirical density: 0.7108771929824561
# 4 - empirical density: 0.7140350877192982
# 5 - empirical density: 0.7105263157894737
# 6 - empirical density: 0.6856140350877193
# 7 - empirical density: 0.7224561403508772
# 8 - empirical density: 0.7189473684210527
# 9 - empirical density: 0.7150877192982457
# 10 - empirical density: 0.727719298245614
# 11 - empirical density: 0.7150877192982457
# 12 - empirical density: 0.716842105263158
# 13 - empirical density: 0.7056140350877192
# 14 - empirical density: 0.7098245614035088
# 15 - empirical density: 0.7136842105263158
# 16 - empirical density: 0.7105263157894737
# 17 - empirical density: 0.716140350877193
# 18 - empirical density: 0.7291228070175438
# 19 - empirical density: 0.7175438596491228
# 0 - empirical density: 0.7252631578947368
# 1 - empirical density: 0.7244736842105263
# 2 - empirical density: 0.715
# 3 - empirical density: 0.7113157894736842
# 4 - empirical density: 0.7052631578947368
# 5 - empirical density: 0.7036842105263158
# 6 - empirical density: 0.7063157894736842
# 7 - empirical density: 0.7060526315789474
# 8 - empirical density: 0.7281578947368421
# 9 - empirical density: 0.7160526315789474
# 10 - empirical density: 0.7178947368421053
# 11 - empirical density: 0.7142105263157895
# 12 - empirical density: 0.7055263157894737
# 13 - empirical density: 0.705
# 14 - empirical density: 0.7215789473684211
# 15 - empirical density: 0.6984210526315789
# 16 - empirical density: 0.7026315789473684
# 17 - empirical density: 0.7128947368421052
# 18 - empirical density: 0.7163157894736842
# 19 - empirical density: 0.7089473684210527
# 0 - empirical density: 0.7014736842105264
# 1 - empirical density: 0.7103157894736842
# 2 - empirical density: 0.7134736842105264
# 3 - empirical density: 0.7141052631578947
# 4 - empirical density: 0.7105263157894737
# 5 - empirical density: 0.7109473684210527
# 6 - empirical density: 0.6976842105263158
# 7 - empirical density: 0.7016842105263158
# 8 - empirical density: 0.7252631578947368
# 9 - empirical density: 0.7103157894736842
# 10 - empirical density: 0.712
# 11 - empirical density: 0.7267368421052631
# 12 - empirical density: 0.716421052631579
# 13 - empirical density: 0.6974736842105264
# 14 - empirical density: 0.7018947368421052
# 15 - empirical density: 0.6945263157894737
# 16 - empirical density: 0.6957894736842105
# 17 - empirical density: 0.7141052631578947
# 18 - empirical density: 0.7307368421052631
# 19 - empirical density: 0.7149473684210527
# 0 - empirical density: 0.7187719298245614
# 1 - empirical density: 0.7121052631578947
# 2 - empirical density: 0.7173684210526315
# 3 - empirical density: 0.7026315789473684
# 4 - empirical density: 0.7077192982456141
# 5 - empirical density: 0.6966666666666667
# 6 - empirical density: 0.6985964912280702
# 7 - empirical density: 0.7154385964912281
# 8 - empirical density: 0.7177192982456141
# 9 - empirical density: 0.7126315789473684
# 10 - empirical density: 0.7214035087719298
# 11 - empirical density: 0.7035087719298245
# 12 - empirical density: 0.7124561403508772
# 13 - empirical density: 0.7045614035087719
# 14 - empirical density: 0.7219298245614035
# 15 - empirical density: 0.7050877192982457
# 16 - empirical density: 0.7078947368421052
# 17 - empirical density: 0.713859649122807
# 18 - empirical density: 0.7219298245614035
# 19 - empirical density: 0.712280701754386
# 0 - empirical density: 0.7150375939849624
# 1 - empirical density: 0.7183458646616542
# 2 - empirical density: 0.7030075187969925
# 3 - empirical density: 0.7112781954887218
# 4 - empirical density: 0.7117293233082707
# 5 - empirical density: 0.7045112781954888
# 6 - empirical density: 0.7037593984962406
# 7 - empirical density: 0.7133834586466166
# 8 - empirical density: 0.7156390977443609
# 9 - empirical density: 0.7117293233082707
# 10 - empirical density: 0.7097744360902256
# 11 - empirical density: 0.7108270676691729
# 12 - empirical density: 0.7090225563909774
# 13 - empirical density: 0.708421052631579
# 14 - empirical density: 0.7231578947368421
# 15 - empirical density: 0.7076691729323308
# 16 - empirical density: 0.7010526315789474
# 17 - empirical density: 0.7030075187969925
# 18 - empirical density: 0.7130827067669173
# 19 - empirical density: 0.7099248120300752
# 0 - empirical density: 0.7121052631578947
# 1 - empirical density: 0.714078947368421
# 2 - empirical density: 0.7109210526315789
# 3 - empirical density: 0.7146052631578947
# 4 - empirical density: 0.7119736842105263
# 5 - empirical density: 0.7042105263157895
# 6 - empirical density: 0.7094736842105264
# 7 - empirical density: 0.7127631578947369
# 8 - empirical density: 0.7251315789473685
# 9 - empirical density: 0.7109210526315789
# 10 - empirical density: 0.7088157894736842
# 11 - empirical density: 0.7110526315789474
# 12 - empirical density: 0.7110526315789474
# 13 - empirical density: 0.7096052631578947
# 14 - empirical density: 0.7042105263157895
# 15 - empirical density: 0.71
# 16 - empirical density: 0.7010526315789474
# 17 - empirical density: 0.7171052631578947
# 18 - empirical density: 0.7144736842105263
# 19 - empirical density: 0.7060526315789474
# 0 - empirical density: 0.7135672514619883
# 1 - empirical density: 0.7042105263157895
# 2 - empirical density: 0.7107602339181287
# 3 - empirical density: 0.7093567251461989
# 4 - empirical density: 0.7129824561403508
# 5 - empirical density: 0.7044444444444444
# 6 - empirical density: 0.707485380116959
# 7 - empirical density: 0.7035087719298245
# 8 - empirical density: 0.7190643274853801
# 9 - empirical density: 0.7092397660818713
# 10 - empirical density: 0.7132163742690059
# 11 - empirical density: 0.7095906432748538
# 12 - empirical density: 0.7119298245614035
# 13 - empirical density: 0.7018713450292398
# 14 - empirical density: 0.7143859649122807
# 15 - empirical density: 0.7033918128654971
# 16 - empirical density: 0.7111111111111111
# 17 - empirical density: 0.707953216374269
# 18 - empirical density: 0.7136842105263158
# 19 - empirical density: 0.7148538011695906
# 0 - empirical density: 0.7118947368421052
# 1 - empirical density: 0.7115789473684211
# 2 - empirical density: 0.704
# 3 - empirical density: 0.7115789473684211
# 4 - empirical density: 0.7118947368421052
# 5 - empirical density: 0.7045263157894737
# 6 - empirical density: 0.7094736842105264
# 7 - empirical density: 0.7109473684210527
# 8 - empirical density: 0.7177894736842105
# 9 - empirical density: 0.7076842105263158
# 10 - empirical density: 0.712421052631579
# 11 - empirical density: 0.710421052631579
# 12 - empirical density: 0.7109473684210527
# 13 - empirical density: 0.7107368421052631
# 14 - empirical density: 0.7058947368421052
# 15 - empirical density: 0.7105263157894737
# 16 - empirical density: 0.7008421052631579
# 17 - empirical density: 0.7126315789473684
# 18 - empirical density: 0.7147368421052631
# 19 - empirical density: 0.7089473684210527
